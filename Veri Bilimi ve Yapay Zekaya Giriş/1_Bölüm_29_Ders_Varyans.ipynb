# %% [markdown]
# # **29.Ders: Varyans**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Varyans, Standart Sapmanın karesidir.
# * Standart Sapmanın karesini aldığımızdan dolayı birden fazla değişkenin dağılımını birbirleriyle kıyaslamak için kullanmak istediğimizde Varyans kullanılması tercih edilebiliyor.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
