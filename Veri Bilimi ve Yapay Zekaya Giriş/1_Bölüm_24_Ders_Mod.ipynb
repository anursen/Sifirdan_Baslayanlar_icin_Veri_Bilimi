# %% [markdown]
# # **24.Ders: Mod**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Elimizdeki serinin herbir değerinin yakalanıp bunların sayılıp sayma işleminden sonra en çok tekrar eden değerin ortaya konması gerekiyor.
# * En çok frekansa sahip değer o serinin modu olmuş oluyor.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
