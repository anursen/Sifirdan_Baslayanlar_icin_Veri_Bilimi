# %% [markdown]
# # **25.Ders: Kartiller**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Hem merkezi eğilim ölçüsü hem de dağılım ölçüsü olarak kullanılabilen kartilleri göreceğiz.
# * Quartile ya da Quantile olarak da karşımıza çıkar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Seriyi küçükten büyüğe doğru sıraladık.
# * Biz ort. ya da medyan ile serinin merkezine gittik.
# * Ama merkezinin %25'lik soluna %25'lik soluna gitmeye kalksak, %25'lik ve %75'lik dilime karşılık gelen değerlere bakalım.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Q2 değeri medyan değeridir.
# * Kartiller serinin merkezi eğilimiyle ilgili bilgi almak için kullanılır.
# * Merkezle beraber merkezin sağından ve solundan da bize bilgi verir kartiller.
