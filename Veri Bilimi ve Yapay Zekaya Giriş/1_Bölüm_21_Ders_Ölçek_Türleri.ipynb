# %% [markdown]
# # **21.Ders: Ölçek Türleri**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Bir değişkenin değerlerini insan olarak okuyup anlayabilmemiz adına bunu ölçmemiz gerekiyor.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Sayısal Değişkenler İçin: Aralık ve Oran**
# * Elimizde bir sıcaklık değeri olduğunda bu sıcaklık değişkeninin negatif ve pozitif değerler alabilir.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Başlangıç noktası sıfır yani yokluğu ifade ediyorsa bu ölçek türüne oran ölçek türü denir.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Araç Fiyatı değişkenindeki değer sıfır olduğunda bir değerinin olmadığını yani bir yokluğu ifade edecektir.
# * KM değeri sıfır ise yine bir yokluğu ifade edecekir.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * **Katgorik Değişkenler:**
# * String formatındaki verilerdir.
# * Cinsiyet değişkeni bir kategorik değişken. Kadın Erkek şeklinde sınıfları var.
# * Kategorik değişkenin sınıfları arasında fark yoksa nominal ölçek türüyle ölçülmüşbir değişkendir.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Sınıfları arasında farklılık varsa yani büyüklük küçüklük ilişkisi kurulabiliyorsa o zaman bu değişkene ordinal ölçek türüyle ölçülmüş kategorik değişken denir.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Ordinal ölçek türüyle ölçülmüş değişkenleriçin rütme adında bir değişken olsun.
# * Biliyoruz ki Onbaşı ile Albay arasında bir rütbe farkı var.
# * Sınıflar arası bir fark var.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Eğitim Durumu isminde elimizde bir değişken olsun.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
